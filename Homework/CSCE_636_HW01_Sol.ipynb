# %% [markdown]
# # HOMEWORK 01
#
# **Submitted by: Diego Sol**
#
# CSCE 636-600: Deep Learning
#
# Professor: Dr. Anxiao Jiang
#
# Code modified from https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/chapter02_mathematical-building-blocks.ipynb

# %% [markdown]
# Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Task 1
#
# **For the neural network in the Jupiter notebook for the MNIST task (which has 2 layers, where the first layer has 512 neurons and the second layer has 10 neurons), adjust the size of the first layer (namely, the number of neurons in the first layer) as: 16, 32, 64, 128, 256, 512. For each size, train the neural network and record its test accuracy (namely, accuracy on the test set). Draw a figure, where the x-axis is the size of the first layer, and the y-axis is the test accuracy. Submit your figure.**

# %% [markdown]
# Number of neurons in the first layer

# %%
num_neurons_L1 = np.array([16,32,64,128,256,512])
annotations_1 = np.ndarray.tolist(num_neurons_L1.astype(str)) # used in labelling points on plot

# %% [markdown]
# Track the accuracy for each iteration

# %%
log_test_acc_1 = np.zeros(num_neurons_L1.shape[0])

# %% [markdown]
# Iterate design of network structure for the different sizes in the first layer

# %%
# number of neurons in the first layer
for xx in range(num_neurons_L1.shape[0]):
        
    # load the MNIST datset in Keras
    from tensorflow.keras.datasets import mnist
    (train_images, train_labels), (test_images, test_labels) = mnist.load_data()

    # network architecture
    model = keras.Sequential([
        layers.Dense(num_neurons_L1[xx], activation="relu"), # number of neurons in this layer vary with each iteration
        layers.Dense(10, activation="softmax")
    ])

    # compilation
    model.compile(optimizer="rmsprop",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])

    # prepare image data (reshape and normalize)
    train_images = train_images.reshape((60000, 28 * 28))
    train_images = train_images.astype("float32") / 255
    test_images = test_images.reshape((10000, 28 * 28))
    test_images = test_images.astype("float32") / 255

    # train the model
    model.fit(train_images, train_labels, epochs=5, batch_size=128)

    # evaluate model accuracy
    test_loss, test_acc = model.evaluate(test_images, test_labels)

    # log accuracy for each iteration
    log_test_acc_1[xx] = test_acc
    print(f"number of neurons in first layer: {num_neurons_L1[xx]}")
    print(f"test accuracy: {test_acc}")
# Out:
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5842 - accuracy: 0.8503
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2961 - accuracy: 0.9162
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2613 - accuracy: 0.9267
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2375 - accuracy: 0.9326
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2201 - accuracy: 0.9366: 0s - loss: 0.2219 - accuracy
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9358
# number of neurons in first layer: 16
# test accuracy: 0.9358000159263611
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4649 - accuracy: 0.8772
# Epoch 2/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2519 - accuracy: 0.9285
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2106 - accuracy: 0.9398
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1829 - accuracy: 0.9471
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1624 - accuracy: 0.9530
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1606 - accuracy: 0.9531
# number of neurons in first layer: 32
# test accuracy: 0.9531000256538391
# Epoch 1/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3873 - accuracy: 0.8952
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1967 - accuracy: 0.9440
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1495 - accuracy: 0.9567
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1220 - accuracy: 0.9645
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1035 - accuracy: 0.9701
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1145 - accuracy: 0.9674
# number of neurons in first layer: 64
# test accuracy: 0.9674000144004822
# Epoch 1/5
# 469/469 [==============================] - 3s 3ms/step - loss: 0.3356 - accuracy: 0.9075
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1603 - accuracy: 0.9537
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1130 - accuracy: 0.9674
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0878 - accuracy: 0.9739
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0714 - accuracy: 0.9790
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9734
# number of neurons in first layer: 128
# test accuracy: 0.9733999967575073
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2920 - accuracy: 0.9175
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1280 - accuracy: 0.9627
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0857 - accuracy: 0.9746
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0638 - accuracy: 0.9809
# Epoch 5/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0499 - accuracy: 0.9847: 0s - loss: 0
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0722 - accuracy: 0.9778: 0s - loss: 0.0855 - accura
# number of neurons in first layer: 256
# test accuracy: 0.9778000116348267
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2604 - accuracy: 0.9238
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1036 - accuracy: 0.9697
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0688 - accuracy: 0.9796
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0499 - accuracy: 0.9855
# Epoch 5/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0378 - accuracy: 0.9889
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0646 - accuracy: 0.9813
# number of neurons in first layer: 512
# test accuracy: 0.9812999963760376

# %% [markdown]
# Print outputs

# %%
print("Model accuracy with different number of neurons in the first layer")
print("--------------------------------------------------")
for ii in range(num_neurons_L1.shape[0]):
    print(f"\nneurons in first layer: {num_neurons_L1[ii]}")
    print(f"test_acc: {log_test_acc_1[ii]}")
# Out:
# Model accuracy with different number of neurons in the first layer
# --------------------------------------------------
#
# neurons in first layer: 16
# test_acc: 0.9358000159263611
#
# neurons in first layer: 32
# test_acc: 0.9531000256538391
#
# neurons in first layer: 64
# test_acc: 0.9674000144004822
#
# neurons in first layer: 128
# test_acc: 0.9733999967575073
#
# neurons in first layer: 256
# test_acc: 0.9778000116348267
#
# neurons in first layer: 512
# test_acc: 0.9812999963760376

# %% [markdown]
# Plot outputs

# %%
fig1, ax1 = plt.subplots()
ax1.plot(num_neurons_L1,log_test_acc_1,marker='o')
for jj, label in enumerate(annotations_1):
    ax1.text(num_neurons_L1[jj],log_test_acc_1[jj],label)
ax1.set_title("Size of first layer vs Test accuracy")
ax1.set_xlabel("Number of neurons in first layer")
ax1.set_ylabel("Test accuracy")
fig1.set_size_inches(10,6)

# %% [markdown]
# We can see from this figure that as the number of neurons in the second layer increase, the accuracy also increases. From visual inspection, this accuracy appears to increase at a logarithmic rate. This means that initially, small incremements in the number of neurons in the first layer have a bigger effect on the accuracy. Larger increments in the number of neurons will see smaller and smaller increments in the accuracy.
#
# Though it is not shown here, multiple runs of this Python script yield highly similar results when compared to each other. In other words, the data outputs in the figure above can consistently be achieved with this code, and it varies minimally with the random variations in batches between runs.

# %% [markdown]
# # Task 2
#
# **For the neural network in the Jupiter notebook for the MNIST task (which has 2 layers, where the first layer has 512 neurons and the second layer has 10 neurons), adjust the number of layers to be: 2, 3, 4, 5. (The last layer has to have size 10 since we have 10 classes. But you can decide on the sizes of the other layers.) For each case, train the neural network and record its test accuracy. Draw a figure, where the x-axis is the number of layers, and the y-axis is the test accuracy. Submit your figure, and specify the sizes of your layers for each case.**

# %% [markdown]
# Number of layers in the network

# %%
num_layers = np.array([2,3,4,5])

# %% [markdown]
# Track the accuracy for each iteration

# %%
log_test_acc_2 = np.zeros((num_layers.shape[0],num_neurons_L1.shape[0]))

# %% [markdown]
# Declare the number of neurons for each layer

# %%
num_neurons = num_neurons_L1 # same as in TASK 1

# %% [markdown]
# Iterate over different numbers of layers and neurons within those layers

# %%
# number of layers in the network
for yy in range(num_layers.shape[0]):

    # number of neurons per layer (except last)
    for xx in range(num_neurons.shape[0]):

        # load the MNIST datset in Keras
        from tensorflow.keras.datasets import mnist
        (train_images, train_labels), (test_images, test_labels) = mnist.load_data()

        # create network
        model = keras.Sequential()

        # network architecture: add layers that vary with iterations
        for zz in range(num_layers[yy]-1):
            model.add(layers.Dense(num_neurons[xx], activation='relu'))

        # final layer is always the same
        model.add(layers.Dense(10, activation='softmax'))

        # compilation
        model.compile(optimizer="rmsprop",
                    loss="sparse_categorical_crossentropy",
                    metrics=["accuracy"])

        # prepare image data (reshape and normalize)
        train_images = train_images.reshape((60000, 28 * 28))
        train_images = train_images.astype("float32") / 255
        test_images = test_images.reshape((10000, 28 * 28))
        test_images = test_images.astype("float32") / 255

        # train the model
        model.fit(train_images, train_labels, epochs=5, batch_size=128)

        # evaluate model accuracy
        test_loss, test_acc = model.evaluate(test_images, test_labels)

        # log accuracy for each iteration
        log_test_acc_2[yy][xx] = test_acc
        print(f"number of layers in the network: {num_layers[yy]}")
        print(f"number of neurons per layer: {num_neurons[xx]}")
        print(f"test accuracy: {test_acc}")
# Out:
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.5725 - accuracy: 0.8533: 0s
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2974 - accuracy: 0.9162
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2640 - accuracy: 0.9257
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2422 - accuracy: 0.9325
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2267 - accuracy: 0.9359
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2222 - accuracy: 0.9369
# number of layers in the network: 2
# number of neurons per layer: 16
# test accuracy: 0.9369000196456909
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4838 - accuracy: 0.8690
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2590 - accuracy: 0.9260
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2167 - accuracy: 0.9388
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1891 - accuracy: 0.9466
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1702 - accuracy: 0.9513
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1639 - accuracy: 0.9521
# number of layers in the network: 2
# number of neurons per layer: 32
# test accuracy: 0.9520999789237976
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4037 - accuracy: 0.8896
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2122 - accuracy: 0.9394
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1617 - accuracy: 0.9539
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1330 - accuracy: 0.9621
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1121 - accuracy: 0.9679
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1146 - accuracy: 0.9655
# number of layers in the network: 2
# number of neurons per layer: 64
# test accuracy: 0.965499997138977
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.9074
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1654 - accuracy: 0.9526
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1174 - accuracy: 0.9660
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0908 - accuracy: 0.9737
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0743 - accuracy: 0.9781
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9756
# number of layers in the network: 2
# number of neurons per layer: 128
# test accuracy: 0.975600004196167
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2855 - accuracy: 0.9195
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1242 - accuracy: 0.9635
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0858 - accuracy: 0.9750
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0647 - accuracy: 0.9808
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0512 - accuracy: 0.9843
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0790 - accuracy: 0.9757
# number of layers in the network: 2
# number of neurons per layer: 256
# test accuracy: 0.9757000207901001
# Epoch 1/5
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2575 - accuracy: 0.9256
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1038 - accuracy: 0.9696
# Epoch 3/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0687 - accuracy: 0.9792
# Epoch 4/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0493 - accuracy: 0.9849
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0373 - accuracy: 0.9888
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0767 - accuracy: 0.9764
# number of layers in the network: 2
# number of neurons per layer: 512
# test accuracy: 0.9764000177383423
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6484 - accuracy: 0.8221
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2998 - accuracy: 0.9136
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2568 - accuracy: 0.9262
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2335 - accuracy: 0.9330
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2163 - accuracy: 0.9370
# 313/313 [==============================] - 0s 946us/step - loss: 0.2199 - accuracy: 0.9351
# number of layers in the network: 3
# number of neurons per layer: 16
# test accuracy: 0.9351000189781189
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4610 - accuracy: 0.8767
# Epoch 2/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2299 - accuracy: 0.9328
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1802 - accuracy: 0.9476
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1507 - accuracy: 0.9552
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1320 - accuracy: 0.9611
# 313/313 [==============================] - 0s 975us/step - loss: 0.1263 - accuracy: 0.9629
# number of layers in the network: 3
# number of neurons per layer: 32
# test accuracy: 0.9628999829292297
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3599 - accuracy: 0.8992
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1707 - accuracy: 0.9495
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1269 - accuracy: 0.9623
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1022 - accuracy: 0.9693
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0868 - accuracy: 0.9743
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1040 - accuracy: 0.9686
# number of layers in the network: 3
# number of neurons per layer: 64
# test accuracy: 0.9685999751091003
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3002 - accuracy: 0.9138
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1262 - accuracy: 0.9620
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0866 - accuracy: 0.9729
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0665 - accuracy: 0.9794
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0515 - accuracy: 0.9843
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9773
# number of layers in the network: 3
# number of neurons per layer: 128
# test accuracy: 0.9772999882698059
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2532 - accuracy: 0.9247
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0959 - accuracy: 0.9707
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0642 - accuracy: 0.9802
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0458 - accuracy: 0.9859
# Epoch 5/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0351 - accuracy: 0.9891
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0698 - accuracy: 0.9811
# number of layers in the network: 3
# number of neurons per layer: 256
# test accuracy: 0.9811000227928162
# Epoch 1/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2195 - accuracy: 0.9308
# Epoch 2/5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0822 - accuracy: 0.9749
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0535 - accuracy: 0.9833
# Epoch 4/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0393 - accuracy: 0.9879
# Epoch 5/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0290 - accuracy: 0.9913
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0715 - accuracy: 0.9819
# number of layers in the network: 3
# number of neurons per layer: 512
# test accuracy: 0.9818999767303467
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7427 - accuracy: 0.7773
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3298 - accuracy: 0.9056
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2671 - accuracy: 0.9228
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2362 - accuracy: 0.9312
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2155 - accuracy: 0.9369
# 313/313 [==============================] - 0s 964us/step - loss: 0.2109 - accuracy: 0.9389
# number of layers in the network: 4
# number of neurons per layer: 16
# test accuracy: 0.9388999938964844
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5117 - accuracy: 0.8564
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2340 - accuracy: 0.9316
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1813 - accuracy: 0.9460
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1538 - accuracy: 0.9540
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1352 - accuracy: 0.9600
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1375 - accuracy: 0.9603
# number of layers in the network: 4
# number of neurons per layer: 32
# test accuracy: 0.9603000283241272
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3603 - accuracy: 0.8971
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1551 - accuracy: 0.9535
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1109 - accuracy: 0.9669
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9738
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0731 - accuracy: 0.9776
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9719
# number of layers in the network: 4
# number of neurons per layer: 64
# test accuracy: 0.9718999862670898
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2948 - accuracy: 0.9121
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1184 - accuracy: 0.9640
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0824 - accuracy: 0.9744
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9799
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0499 - accuracy: 0.9847
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9761
# number of layers in the network: 4
# number of neurons per layer: 128
# test accuracy: 0.9761000275611877
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2485 - accuracy: 0.9240
# Epoch 2/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0960 - accuracy: 0.9703
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0641 - accuracy: 0.9807
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0488 - accuracy: 0.9851
# Epoch 5/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0370 - accuracy: 0.9882
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0753 - accuracy: 0.9783
# number of layers in the network: 4
# number of neurons per layer: 256
# test accuracy: 0.9782999753952026
# Epoch 1/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2357 - accuracy: 0.9263
# Epoch 2/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0878 - accuracy: 0.9742
# Epoch 3/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0609 - accuracy: 0.9822
# Epoch 4/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0484 - accuracy: 0.9860
# Epoch 5/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0376 - accuracy: 0.9896
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1007 - accuracy: 0.9791
# number of layers in the network: 4
# number of neurons per layer: 512
# test accuracy: 0.9790999889373779
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.8133 - accuracy: 0.7523
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3406 - accuracy: 0.9014
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2793 - accuracy: 0.9172
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2455 - accuracy: 0.9275
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2228 - accuracy: 0.9347
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2255 - accuracy: 0.9388
# number of layers in the network: 5
# number of neurons per layer: 16
# test accuracy: 0.9387999773025513
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4983 - accuracy: 0.8545
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2321 - accuracy: 0.9317
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.9475
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1491 - accuracy: 0.9559
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1295 - accuracy: 0.9616
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9553
# number of layers in the network: 5
# number of neurons per layer: 32
# test accuracy: 0.955299973487854
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3841 - accuracy: 0.8856
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1639 - accuracy: 0.9512
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1196 - accuracy: 0.9634
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0945 - accuracy: 0.9720
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0788 - accuracy: 0.9760
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1165 - accuracy: 0.9666
# number of layers in the network: 5
# number of neurons per layer: 64
# test accuracy: 0.9666000008583069
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3087 - accuracy: 0.9048
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1200 - accuracy: 0.9635
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0835 - accuracy: 0.9749
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0638 - accuracy: 0.9804
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0515 - accuracy: 0.9837
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9722
# number of layers in the network: 5
# number of neurons per layer: 128
# test accuracy: 0.9721999764442444
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2695 - accuracy: 0.9152
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1062 - accuracy: 0.9682
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0729 - accuracy: 0.9787
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0546 - accuracy: 0.9833
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0442 - accuracy: 0.9873
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1280 - accuracy: 0.9720
# number of layers in the network: 5
# number of neurons per layer: 256
# test accuracy: 0.972000002861023
# Epoch 1/5
# 469/469 [==============================] - 10s 21ms/step - loss: 0.2715 - accuracy: 0.9184
# Epoch 2/5
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1031 - accuracy: 0.9705
# Epoch 3/5
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0719 - accuracy: 0.9793
# Epoch 4/5
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0594 - accuracy: 0.9840
# Epoch 5/5
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0515 - accuracy: 0.9868
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1418 - accuracy: 0.9701
# number of layers in the network: 5
# number of neurons per layer: 512
# test accuracy: 0.9700999855995178

# %% [markdown]
# Print outputs

# %%
print(f"Model accuracy with different number of layers in the network")
print("--------------------------------------------------\n")
for ii in range(num_layers.shape[0]):
    for jj in range(num_neurons.shape[0]):
        print(f"number of layers in the network: {num_layers[ii]}")
        print(f"number of neurons per layer: {num_neurons[jj]}")
        print(f"test_acc: {log_test_acc_2[ii][jj]}\n")
# Out:
# Model accuracy with different number of layers in the network
# --------------------------------------------------
#
# number of layers in the network: 2
# number of neurons per layer: 16
# test_acc: 0.9369000196456909
#
# number of layers in the network: 2
# number of neurons per layer: 32
# test_acc: 0.9520999789237976
#
# number of layers in the network: 2
# number of neurons per layer: 64
# test_acc: 0.965499997138977
#
# number of layers in the network: 2
# number of neurons per layer: 128
# test_acc: 0.975600004196167
#
# number of layers in the network: 2
# number of neurons per layer: 256
# test_acc: 0.9757000207901001
#
# number of layers in the network: 2
# number of neurons per layer: 512
# test_acc: 0.9764000177383423
#
# number of layers in the network: 3
# number of neurons per layer: 16
# test_acc: 0.9351000189781189
#
# number of layers in the network: 3
# number of neurons per layer: 32
# test_acc: 0.9628999829292297
#
# number of layers in the network: 3
# number of neurons per layer: 64
# test_acc: 0.9685999751091003
#
# number of layers in the network: 3
# number of neurons per layer: 128
# test_acc: 0.9772999882698059
#
# number of layers in the network: 3
# number of neurons per layer: 256
# test_acc: 0.9811000227928162
#
# number of layers in the network: 3
# number of neurons per layer: 512
# test_acc: 0.9818999767303467
#
# number of layers in the network: 4
# number of neurons per layer: 16
# test_acc: 0.9388999938964844
#
# number of layers in the network: 4
# number of neurons per layer: 32
# test_acc: 0.9603000283241272
#
# number of layers in the network: 4
# number of neurons per layer: 64
# test_acc: 0.9718999862670898
#
# number of layers in the network: 4
# number of neurons per layer: 128
# test_acc: 0.9761000275611877
#
# number of layers in the network: 4
# number of neurons per layer: 256
# test_acc: 0.9782999753952026
#
# number of layers in the network: 4
# number of neurons per layer: 512
# test_acc: 0.9790999889373779
#
# number of layers in the network: 5
# number of neurons per layer: 16
# test_acc: 0.9387999773025513
#
# number of layers in the network: 5
# number of neurons per layer: 32
# test_acc: 0.955299973487854
#
# number of layers in the network: 5
# number of neurons per layer: 64
# test_acc: 0.9666000008583069
#
# number of layers in the network: 5
# number of neurons per layer: 128
# test_acc: 0.9721999764442444
#
# number of layers in the network: 5
# number of neurons per layer: 256
# test_acc: 0.972000002861023
#
# number of layers in the network: 5
# number of neurons per layer: 512
# test_acc: 0.9700999855995178

# %% [markdown]
# Plot outputs

# %%
fig2, ax2 = plt.subplots()
for ii in range(num_neurons.shape[0]):
    ax2.plot(num_layers,log_test_acc_2[:,ii],marker='o',label=str(num_neurons[ii]) + ' neurons')
ax2.set_title("Number of layers vs Test accuracy")
ax2.set_xlabel("Number of layers in the network")
ax2.set_ylabel("Test accuracy")
ax2.set_xticks(num_layers)
ax2.set_xlim([1.85,6])
ax2.legend()
fig2.set_size_inches(10,6)

# %% [markdown]
# We can see from this figure that as the number of layers in the network increase, the accuracy for each of the curves varies slightly in a seemingly random fashion. This means that adding more layers to the neural network will not consitently increase the test accuracy (at least not for hidden layers that share the same number of neurons as was tested in this script).
#
# Though it is not shown here, multiple runs of this Python script yield different results when compared to each other. The variations appear the same in magnitude, but precise peaks and dips in accuracy for each curve changes based on the run. In other words, the exact data outputs in the figure above cannot consistently be achieved with this code, and it varies with the random variations in batches between runs.

# %% [markdown]
# # Deliverables
#
# **Save subplot**

# %%
fig, ax = plt.subplots(1,2)
fig.suptitle("CSCE 636 Homework 01 - Diego Sol")

ax[0].plot(num_neurons_L1,log_test_acc_1,marker='o')
for jj, label in enumerate(annotations_1):
    ax[0].text(num_neurons_L1[jj],log_test_acc_1[jj],label)
ax[0].set_title("TASK 1: Size of first layer vs Test accuracy")
ax[0].set_xlabel("Number of neurons in first layer")
ax[0].set_ylabel("Test accuracy")

for ii in range(num_neurons.shape[0]):
    ax[1].plot(num_layers,log_test_acc_2[:,ii],marker='o',label=str(num_neurons[ii]) + ' neurons')
ax[1].set_title("TASK 2: Number of layers vs Test accuracy")
ax[1].set_xlabel("Number of layers in the network")
ax[1].set_ylabel("Test accuracy")
ax[1].set_xticks(num_layers)
ax[1].set_xlim([1.85,6])
ax[1].legend()

fig.set_size_inches(20,6)
fig.savefig("CSCE_636_HW01_fig.png")
