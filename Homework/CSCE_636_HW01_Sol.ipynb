# %% [markdown]
# # HOMEWORK 01
#
# **Submitted by: Diego Sol**
#
# CSCE 636-600: Deep Learning
#
# Professor: Dr. Anxiao Jiang
#
# Code modified from https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/chapter02_mathematical-building-blocks.ipynb

# %% [markdown]
# Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Task 1
#
# **For the neural network in the Jupiter notebook for the MNIST task (which has 2 layers, where the first layer has 512 neurons and the second layer has 10 neurons), adjust the size of the first layer (namely, the number of neurons in the first layer) as: 16, 32, 64, 128, 256, 512. For each size, train the neural network and record its test accuracy (namely, accuracy on the test set). Draw a figure, where the x-axis is the size of the first layer, and the y-axis is the test accuracy. Submit your figure.**

# %% [markdown]
# Number of neurons in the first layer

# %%
num_neurons_L1 = np.array([16,32,64,128,256,512])
annotations_1 = np.ndarray.tolist(num_neurons_L1.astype(str)) # used in labelling points on plot

# %% [markdown]
# Track the accuracy for each iteration

# %%
log_test_acc_1 = np.zeros(num_neurons_L1.shape[0])

# %% [markdown]
# Iterate design of network structure for the different sizes in the first layer

# %%
# number of neurons in the first layer
for xx in range(num_neurons_L1.shape[0]):
        
    # load the MNIST datset in Keras
    from tensorflow.keras.datasets import mnist
    (train_images, train_labels), (test_images, test_labels) = mnist.load_data()

    # network architecture
    model = keras.Sequential([
        layers.Dense(num_neurons_L1[xx], activation="relu"), # number of neurons in this layer vary with each iteration
        layers.Dense(10, activation="softmax")
    ])

    # compilation
    model.compile(optimizer="rmsprop",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])

    # prepare image data (reshape and normalize)
    train_images = train_images.reshape((60000, 28 * 28))
    train_images = train_images.astype("float32") / 255
    test_images = test_images.reshape((10000, 28 * 28))
    test_images = test_images.astype("float32") / 255

    # train the model
    model.fit(train_images, train_labels, epochs=5, batch_size=128)

    # evaluate model accuracy
    test_loss, test_acc = model.evaluate(test_images, test_labels)

    # log accuracy for each iteration
    log_test_acc_1[xx] = test_acc
    print(f"number of neurons in first layer: {num_neurons_L1[xx]}")
    print(f"test accuracy: {test_acc}")
# Out:
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5932 - accuracy: 0.8393
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3032 - accuracy: 0.9140
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2664 - accuracy: 0.9239
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2439 - accuracy: 0.9311
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2272 - accuracy: 0.9350
# 313/313 [==============================] - 0s 981us/step - loss: 0.2236 - accuracy: 0.9366
# number of neurons in first layer: 16
# test accuracy: 0.9366000294685364
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4776 - accuracy: 0.8740
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2449 - accuracy: 0.9316
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2000 - accuracy: 0.9444
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1731 - accuracy: 0.9514
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1558 - accuracy: 0.9559
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1582 - accuracy: 0.9536
# number of neurons in first layer: 32
# test accuracy: 0.9535999894142151
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3871 - accuracy: 0.8952
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2016 - accuracy: 0.9424
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1545 - accuracy: 0.9558
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1264 - accuracy: 0.9640
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1076 - accuracy: 0.9700
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1247 - accuracy: 0.9637
# number of neurons in first layer: 64
# test accuracy: 0.963699996471405
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3317 - accuracy: 0.9089
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1574 - accuracy: 0.9539
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1130 - accuracy: 0.9669
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0876 - accuracy: 0.9743
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0713 - accuracy: 0.9794
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0851 - accuracy: 0.9742
# number of neurons in first layer: 128
# test accuracy: 0.9742000102996826
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2885 - accuracy: 0.9186
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1255 - accuracy: 0.9630
# Epoch 3/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0853 - accuracy: 0.9739
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0640 - accuracy: 0.9808
# Epoch 5/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0498 - accuracy: 0.9850
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0733 - accuracy: 0.9781
# number of neurons in first layer: 256
# test accuracy: 0.9781000018119812
# Epoch 1/5
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2594 - accuracy: 0.9259
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1028 - accuracy: 0.9695
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0681 - accuracy: 0.9798
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0499 - accuracy: 0.9846
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0373 - accuracy: 0.9887
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0659 - accuracy: 0.9814
# number of neurons in first layer: 512
# test accuracy: 0.9814000129699707

# %% [markdown]
# Print outputs

# %%
print("Model accuracy with different number of neurons in the first layer")
print("--------------------------------------------------")
for ii in range(num_neurons_L1.shape[0]):
    print(f"\nneurons in first layer: {num_neurons_L1[ii]}")
    print(f"test_acc: {log_test_acc_1[ii]}")
# Out:
# Model accuracy with different number of neurons in the first layer
# --------------------------------------------------
#
# neurons in first layer: 16
# test_acc: 0.9366000294685364
#
# neurons in first layer: 32
# test_acc: 0.9535999894142151
#
# neurons in first layer: 64
# test_acc: 0.963699996471405
#
# neurons in first layer: 128
# test_acc: 0.9742000102996826
#
# neurons in first layer: 256
# test_acc: 0.9781000018119812
#
# neurons in first layer: 512
# test_acc: 0.9814000129699707

# %% [markdown]
# Plot outputs

# %%
fig1, ax1 = plt.subplots()
ax1.plot(num_neurons_L1,log_test_acc_1,marker='o')
for jj, label in enumerate(annotations_1):
    ax1.text(num_neurons_L1[jj],log_test_acc_1[jj],label)
ax1.set_title("Size of first layer vs Test accuracy")
ax1.set_xlabel("Number of neurons in first layer")
ax1.set_ylabel("Test accuracy")
fig1.set_size_inches(10,6)

# %% [markdown]
# We can see from this figure that as the number of neurons in the second layer increase, the accuracy also increases. From visual inspection, this accuracy appears to increase at a logarithmic rate. This means that initially, small incremements in the number of neurons in the first layer have a bigger effect on the accuracy. Larger increments in the number of neurons will see smaller and smaller increments in the accuracy.
#
# Though it is not shown here, multiple runs of this Python script yield highly similar results when compared to each other. In other words, the data outputs in the figure above can consistently be achieved with this code, and it varies minimally with the random variations in batches between runs.

# %% [markdown]
# # Task 2
#
# **For the neural network in the Jupiter notebook for the MNIST task (which has 2 layers, where the first layer has 512 neurons and the second layer has 10 neurons), adjust the number of layers to be: 2, 3, 4, 5. (The last layer has to have size 10 since we have 10 classes. But you can decide on the sizes of the other layers.) For each case, train the neural network and record its test accuracy. Draw a figure, where the x-axis is the number of layers, and the y-axis is the test accuracy. Submit your figure, and specify the sizes of your layers for each case.**

# %% [markdown]
# Number of layers in the network

# %%
num_layers = np.array([2,3,4,5])

# %% [markdown]
# Track the accuracy for each iteration

# %%
log_test_acc_2 = np.zeros((num_layers.shape[0],num_neurons_L1.shape[0]))

# %% [markdown]
# Declare the number of neurons for each layer

# %%
num_neurons = num_neurons_L1 # same as in TASK 1

# %% [markdown]
# Iterate over different numbers of layers and neurons within those layers

# %%
# number of layers in the network
for yy in range(num_layers.shape[0]):

    # number of neurons per layer (except last)
    for xx in range(num_neurons.shape[0]):

        # load the MNIST datset in Keras
        from tensorflow.keras.datasets import mnist
        (train_images, train_labels), (test_images, test_labels) = mnist.load_data()

        # create network
        model = keras.Sequential()

        # network architecture: add layers that vary with iterations
        for zz in range(num_layers[yy]-1):
            model.add(layers.Dense(num_neurons[xx], activation='relu'))

        # final layer is always the same
        model.add(layers.Dense(10, activation='softmax'))

        # compilation
        model.compile(optimizer="rmsprop",
                    loss="sparse_categorical_crossentropy",
                    metrics=["accuracy"])

        # prepare image data (reshape and normalize)
        train_images = train_images.reshape((60000, 28 * 28))
        train_images = train_images.astype("float32") / 255
        test_images = test_images.reshape((10000, 28 * 28))
        test_images = test_images.astype("float32") / 255

        # train the model
        model.fit(train_images, train_labels, epochs=5, batch_size=128)

        # evaluate model accuracy
        test_loss, test_acc = model.evaluate(test_images, test_labels)

        # log accuracy for each iteration
        log_test_acc_2[yy][xx] = test_acc
        print(f"number of layers in the network: {num_layers[yy]}")
        print(f"number of neurons per layer: {num_neurons[xx]}")
        print(f"test accuracy: {test_acc}")
# Out:
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5592 - accuracy: 0.8490
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2870 - accuracy: 0.9184
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2496 - accuracy: 0.9292
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2280 - accuracy: 0.9356
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2135 - accuracy: 0.9401
# 313/313 [==============================] - 0s 957us/step - loss: 0.2133 - accuracy: 0.9406
# number of layers in the network: 2
# number of neurons per layer: 16
# test accuracy: 0.9405999779701233
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4578 - accuracy: 0.8806
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2409 - accuracy: 0.9312
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2002 - accuracy: 0.9426
# Epoch 4/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1749 - accuracy: 0.9493
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1575 - accuracy: 0.9545
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1595 - accuracy: 0.9531
# number of layers in the network: 2
# number of neurons per layer: 32
# test accuracy: 0.9531000256538391
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8935
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2046 - accuracy: 0.9418
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1576 - accuracy: 0.9544
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1293 - accuracy: 0.9630
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9685
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9661
# number of layers in the network: 2
# number of neurons per layer: 64
# test accuracy: 0.9660999774932861
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3355 - accuracy: 0.9079
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1578 - accuracy: 0.9552
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1124 - accuracy: 0.9679
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0879 - accuracy: 0.9743
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0723 - accuracy: 0.9788
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0864 - accuracy: 0.9744
# number of layers in the network: 2
# number of neurons per layer: 128
# test accuracy: 0.974399983882904
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2849 - accuracy: 0.9199
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1246 - accuracy: 0.9630
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0849 - accuracy: 0.9746
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0644 - accuracy: 0.9810
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0502 - accuracy: 0.9852
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9771
# number of layers in the network: 2
# number of neurons per layer: 256
# test accuracy: 0.9771000146865845
# Epoch 1/5
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2570 - accuracy: 0.9260
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1023 - accuracy: 0.9689
# Epoch 3/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0687 - accuracy: 0.9797
# Epoch 4/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0494 - accuracy: 0.9853
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0373 - accuracy: 0.9888
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0632 - accuracy: 0.9804
# number of layers in the network: 2
# number of neurons per layer: 512
# test accuracy: 0.980400025844574
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.6639 - accuracy: 0.8154
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2846 - accuracy: 0.9193
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2432 - accuracy: 0.9304
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2194 - accuracy: 0.9375
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2018 - accuracy: 0.9429
# 313/313 [==============================] - 0s 981us/step - loss: 0.1968 - accuracy: 0.9416
# number of layers in the network: 3
# number of neurons per layer: 16
# test accuracy: 0.9416000247001648
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4489 - accuracy: 0.8760
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2168 - accuracy: 0.9377
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1767 - accuracy: 0.9488
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1535 - accuracy: 0.9550
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9601
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1402 - accuracy: 0.9575
# number of layers in the network: 3
# number of neurons per layer: 32
# test accuracy: 0.9574999809265137
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3625 - accuracy: 0.8987
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1670 - accuracy: 0.9513
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1239 - accuracy: 0.9630
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0986 - accuracy: 0.9707
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0824 - accuracy: 0.9756
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 0.9699
# number of layers in the network: 3
# number of neurons per layer: 64
# test accuracy: 0.9699000120162964
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3048 - accuracy: 0.9115
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1253 - accuracy: 0.9622
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0855 - accuracy: 0.9738
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0648 - accuracy: 0.9804
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0513 - accuracy: 0.9846
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0944 - accuracy: 0.9725
# number of layers in the network: 3
# number of neurons per layer: 128
# test accuracy: 0.9725000262260437
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2497 - accuracy: 0.9253
# Epoch 2/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0959 - accuracy: 0.9702
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0644 - accuracy: 0.9804
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0475 - accuracy: 0.9849
# Epoch 5/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0366 - accuracy: 0.9886
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0676 - accuracy: 0.9810
# number of layers in the network: 3
# number of neurons per layer: 256
# test accuracy: 0.9810000061988831
# Epoch 1/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2189 - accuracy: 0.9331
# Epoch 2/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0805 - accuracy: 0.9755
# Epoch 3/5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0525 - accuracy: 0.9835
# Epoch 4/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0388 - accuracy: 0.9881
# Epoch 5/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0293 - accuracy: 0.9912
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0777 - accuracy: 0.9806: 0s - loss: 0
# number of layers in the network: 3
# number of neurons per layer: 512
# test accuracy: 0.9805999994277954
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.7267 - accuracy: 0.7869
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2927 - accuracy: 0.9149
# Epoch 3/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2406 - accuracy: 0.9299
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2112 - accuracy: 0.9390
# Epoch 5/5
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1917 - accuracy: 0.9451
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9455
# number of layers in the network: 4
# number of neurons per layer: 16
# test accuracy: 0.9455000162124634
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4751 - accuracy: 0.8632
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2214 - accuracy: 0.9360
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1772 - accuracy: 0.9476
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1507 - accuracy: 0.9554
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1340 - accuracy: 0.9607
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1350 - accuracy: 0.9593
# number of layers in the network: 4
# number of neurons per layer: 32
# test accuracy: 0.9592999815940857
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3632 - accuracy: 0.8961
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1568 - accuracy: 0.9535
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1145 - accuracy: 0.9655
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.9725
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0753 - accuracy: 0.9770
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9685
# number of layers in the network: 4
# number of neurons per layer: 64
# test accuracy: 0.968500018119812
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3002 - accuracy: 0.9104
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1192 - accuracy: 0.9634
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0829 - accuracy: 0.9750
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0623 - accuracy: 0.9808
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0497 - accuracy: 0.9847
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9783
# number of layers in the network: 4
# number of neurons per layer: 128
# test accuracy: 0.9782999753952026
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2558 - accuracy: 0.9204
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0954 - accuracy: 0.9701
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0648 - accuracy: 0.9797
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0489 - accuracy: 0.9848
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9884
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0842 - accuracy: 0.9796
# number of layers in the network: 4
# number of neurons per layer: 256
# test accuracy: 0.9796000123023987
# Epoch 1/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2363 - accuracy: 0.9271
# Epoch 2/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0884 - accuracy: 0.9731
# Epoch 3/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0616 - accuracy: 0.9821
# Epoch 4/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0468 - accuracy: 0.9863
# Epoch 5/5
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0389 - accuracy: 0.9886
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1123 - accuracy: 0.9775
# number of layers in the network: 4
# number of neurons per layer: 512
# test accuracy: 0.9775000214576721
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7957 - accuracy: 0.7497
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3275 - accuracy: 0.9062
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.9214
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2424 - accuracy: 0.9305
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2216 - accuracy: 0.9359
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9333
# number of layers in the network: 5
# number of neurons per layer: 16
# test accuracy: 0.9333000183105469
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.4996 - accuracy: 0.8526
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2113 - accuracy: 0.9369
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1672 - accuracy: 0.9491
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1416 - accuracy: 0.9568
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1236 - accuracy: 0.9624
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 0.9595
# number of layers in the network: 5
# number of neurons per layer: 32
# test accuracy: 0.9595000147819519
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3752 - accuracy: 0.8870
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1598 - accuracy: 0.9520
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1193 - accuracy: 0.9638
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0946 - accuracy: 0.9709
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.9765
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1041 - accuracy: 0.9685
# number of layers in the network: 5
# number of neurons per layer: 64
# test accuracy: 0.968500018119812
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3004 - accuracy: 0.9064
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1202 - accuracy: 0.9635
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0818 - accuracy: 0.9747
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0647 - accuracy: 0.9798
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0512 - accuracy: 0.9838
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0950 - accuracy: 0.9718
# number of layers in the network: 5
# number of neurons per layer: 128
# test accuracy: 0.9718000292778015
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2717 - accuracy: 0.9150
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1024 - accuracy: 0.9696
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0727 - accuracy: 0.9780
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0547 - accuracy: 0.9838
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0437 - accuracy: 0.9870
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1005 - accuracy: 0.9770
# number of layers in the network: 5
# number of neurons per layer: 256
# test accuracy: 0.9769999980926514
# Epoch 1/5
# 469/469 [==============================] - 13s 25ms/step - loss: 0.2657 - accuracy: 0.9178
# Epoch 2/5
# 469/469 [==============================] - 12s 25ms/step - loss: 0.1010 - accuracy: 0.9713
# Epoch 3/5
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0730 - accuracy: 0.97950s - loss: 0.0734 - accuracy:
# Epoch 4/5
# 469/469 [==============================] - 12s 25ms/step - loss: 0.0628 - accuracy: 0.9834
# Epoch 5/5
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0534 - accuracy: 0.9861
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1190 - accuracy: 0.9772
# number of layers in the network: 5
# number of neurons per layer: 512
# test accuracy: 0.9771999716758728

# %% [markdown]
# Print outputs

# %%
print(f"Model accuracy with different number of layers in the network")
print("--------------------------------------------------\n")
for ii in range(num_layers.shape[0]):
    for jj in range(num_neurons.shape[0]):
        print(f"number of layers in the network: {num_layers[ii]}")
        print(f"number of neurons per layer: {num_neurons[jj]}")
        print(f"test_acc: {log_test_acc_2[ii][jj]}\n")
# Out:
# Model accuracy with different number of layers in the network
# --------------------------------------------------
#
# number of layers in the network: 2
# number of neurons per layer: 16
# test_acc: 0.9405999779701233
#
# number of layers in the network: 2
# number of neurons per layer: 32
# test_acc: 0.9531000256538391
#
# number of layers in the network: 2
# number of neurons per layer: 64
# test_acc: 0.9660999774932861
#
# number of layers in the network: 2
# number of neurons per layer: 128
# test_acc: 0.974399983882904
#
# number of layers in the network: 2
# number of neurons per layer: 256
# test_acc: 0.9771000146865845
#
# number of layers in the network: 2
# number of neurons per layer: 512
# test_acc: 0.980400025844574
#
# number of layers in the network: 3
# number of neurons per layer: 16
# test_acc: 0.9416000247001648
#
# number of layers in the network: 3
# number of neurons per layer: 32
# test_acc: 0.9574999809265137
#
# number of layers in the network: 3
# number of neurons per layer: 64
# test_acc: 0.9699000120162964
#
# number of layers in the network: 3
# number of neurons per layer: 128
# test_acc: 0.9725000262260437
#
# number of layers in the network: 3
# number of neurons per layer: 256
# test_acc: 0.9810000061988831
#
# number of layers in the network: 3
# number of neurons per layer: 512
# test_acc: 0.9805999994277954
#
# number of layers in the network: 4
# number of neurons per layer: 16
# test_acc: 0.9455000162124634
#
# number of layers in the network: 4
# number of neurons per layer: 32
# test_acc: 0.9592999815940857
#
# number of layers in the network: 4
# number of neurons per layer: 64
# test_acc: 0.968500018119812
#
# number of layers in the network: 4
# number of neurons per layer: 128
# test_acc: 0.9782999753952026
#
# number of layers in the network: 4
# number of neurons per layer: 256
# test_acc: 0.9796000123023987
#
# number of layers in the network: 4
# number of neurons per layer: 512
# test_acc: 0.9775000214576721
#
# number of layers in the network: 5
# number of neurons per layer: 16
# test_acc: 0.9333000183105469
#
# number of layers in the network: 5
# number of neurons per layer: 32
# test_acc: 0.9595000147819519
#
# number of layers in the network: 5
# number of neurons per layer: 64
# test_acc: 0.968500018119812
#
# number of layers in the network: 5
# number of neurons per layer: 128
# test_acc: 0.9718000292778015
#
# number of layers in the network: 5
# number of neurons per layer: 256
# test_acc: 0.9769999980926514
#
# number of layers in the network: 5
# number of neurons per layer: 512
# test_acc: 0.9771999716758728

# %% [markdown]
# Plot outputs

# %%
fig2, ax2 = plt.subplots()
for ii in range(num_neurons.shape[0]):
    ax2.plot(num_layers,log_test_acc_2[:,ii],marker='o',label=str(num_neurons[ii]) + ' neurons')
ax2.set_title("Number of layers vs Test accuracy")
ax2.set_xlabel("Number of layers in the network")
ax2.set_ylabel("Test accuracy")
ax2.set_xticks(num_layers)
ax2.set_xlim([1.85,6])
ax2.legend()
fig2.set_size_inches(10,6)

# %% [markdown]
# We can see from this figure that as the number of layers in the network increase, the accuracy for each of the curves varies slightly in a seemingly random fashion. This means that adding more layers to the neural network will not consitently increase the test accuracy (at least not for hidden layers that share the same number of neurons as was tested in this script).
#
# Though it is not shown here, multiple runs of this Python script yield different results when compared to each other. The variations appear the same in magnitude, but precise peaks and dips in accuracy for each curve changes based on the run. In other words, the exact data outputs in the figure above cannot consistently be achieved with this code, and it varies with the random variations in batches between runs.

# %% [markdown]
# # Deliverables
#
# **Save subplot**

# %%
fig, ax = plt.subplots(1,2)
fig.suptitle("CSCE 636 Homework 01 - Diego Sol")

ax[0].plot(num_neurons_L1,log_test_acc_1,marker='o')
for jj, label in enumerate(annotations_1):
    ax[0].text(num_neurons_L1[jj],log_test_acc_1[jj],label)
ax[0].set_title("TASK 1: Size of first layer vs Test accuracy")
ax[0].set_xlabel("Number of neurons in first layer")
ax[0].set_ylabel("Test accuracy")

for ii in range(num_neurons.shape[0]):
    ax[1].plot(num_layers,log_test_acc_2[:,ii],marker='o',label=str(num_neurons[ii]) + ' neurons')
ax[1].set_title("TASK 2: Number of layers vs Test accuracy")
ax[1].set_xlabel("Number of layers in the network")
ax[1].set_ylabel("Test accuracy")
ax[1].set_xticks(num_layers)
ax[1].set_xlim([1.85,6])
ax[1].legend()

fig.set_size_inches(20,6)
fig.savefig("CSCE_636_HW01_fig.png")
